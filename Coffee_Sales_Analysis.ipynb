# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Coffee Production Stats
#
# * Create a bar chart of the top 10 coffee producers by total production in 'total-production.csv', sorted from highest to lowest. Change the xticks to two letter country abbreviations.
#
#
# * Data Prep Code
#
# <mark style="background-color: #000000"> coffee_production = pd.read_csv("coffee/total-production.csv").T </mark>
#
# <mark style="background-color: #000000"> coffee_production.columns = coffee_production.iloc[0] </mark>
#
# <mark style="background-color: #000000"> coffee_production = coffee_production.drop("total_production") </mark>

# %%
coffee_production = pd.read_csv(
    "/Users/huzaifamalik/Downloads/Python for Data Analytics/Data Visualization with Matplotlib & Seaborn/Data Viz with Matplotlib & Seaborn/Data/coffee/total-production.csv"
)

# %%
coffee_production.head()
# Out:
#                    total_production        1990        1991        1992  \
# 0                            Angola     50.3450     79.3310     77.5200
# 1  Bolivia (Plurinational State of)    122.7770    103.5360    120.2350
# 2                            Brazil  27285.6286  27293.4934  34603.3542
# 3                           Burundi    487.3930    667.1990    620.2380
# 4                           Ecuador   1503.8150   2123.8240   1185.4800
#
#          1993       1994        1995       1996       1997        1998  ...  \
# 0     32.6080     76.802     62.1090     70.925     64.330     85.3440  ...
# 1     50.8230    116.944    142.4850    124.579    140.719    137.9850  ...
# 2  28166.9786  28192.047  18060.2022  29196.743  26148.004  36760.8533  ...
# 3    393.3540    664.143    433.9800    400.969    249.785    491.9920  ...
# 4   2069.0070   2375.766   1888.2330   1992.914   1190.663   1205.9680  ...
#
# ...

# %%
coffee_production.shape
# Out:
# (56, 30)

# %%
coffee_production["total_production"].nunique()
# Out:
# 56

# %%
#Create a bar chart of the top 10 coffee producers by total production in 'total-production.csv', 
#Sorted from highest to lowest. Change the xticks to two letter country abbreviations.

# %%
country_coffee_data = coffee_production.iloc[:,1:]

# %%
country_coffee_data.head()
# Out:
#          1990        1991        1992        1993       1994        1995  \
# 0     50.3450     79.3310     77.5200     32.6080     76.802     62.1090
# 1    122.7770    103.5360    120.2350     50.8230    116.944    142.4850
# 2  27285.6286  27293.4934  34603.3542  28166.9786  28192.047  18060.2022
# 3    487.3930    667.1990    620.2380    393.3540    664.143    433.9800
# 4   1503.8150   2123.8240   1185.4800   2069.0070   2375.766   1888.2330
#
#         1996       1997        1998        1999  ...        2009        2010  \
# 0     70.925     64.330     85.3440     54.9390  ...     13.4200     34.9700
# 1    124.579    140.719    137.9850    157.7020  ...    128.4751    117.2249
# 2  29196.743  26148.004  36760.8533  47577.8065  ...  43976.8120  55428.4102
# 3    400.969    249.785    491.9920    350.5500  ...    111.6130    352.9776
# 4   1992.914   1190.663   1205.9680   1197.6832  ...    813.2849    853.9798
#
# ...

# %%
total_columns = len(country_coffee_data.columns)

# %%
total_columns
# Out:
# 29

# %%
total_rows = country_coffee_data.shape[0]

# %%
total_rows
# Out:
# 56

# %%
total_production_each_country_array = []

for i in range(0,total_rows,1): 
    total = 0.0
    
    for j in range(0,total_columns,1):  
        total += country_coffee_data.iloc[i,j]
    
    total_production_each_country_array.append(float(total))

# %%
coffee_production["total_production"].values
# Out:
# array(['Angola', 'Bolivia (Plurinational State of)', 'Brazil', 'Burundi',
#        'Ecuador', 'Indonesia', 'Madagascar', 'Malawi', 'Papua New Guinea',
#        'Paraguay', 'Peru', 'Rwanda', 'Timor-Leste', 'Zimbabwe', 'Congo',
#        'Cuba', 'Dominican Republic', 'Haiti', 'Philippines', 'Tanzania',
#        'Zambia', 'Benin', 'Cameroon', 'Central African Republic',
#        'Colombia', 'Costa Rica', "Côte d'Ivoire",
#        'Democratic Republic of Congo', 'El Salvador', 'Equatorial Guinea',
#        'Ethiopia', 'Gabon', 'Ghana', 'Guatemala', 'Guinea', 'Guyana',
#        'Honduras', 'India', 'Jamaica', 'Kenya',
#        "Lao People's Democratic Republic", 'Liberia', 'Mexico', 'Nepal',
#        'Nicaragua', 'Nigeria', 'Panama', 'Sierra Leone', 'Sri Lanka',
#        'Thailand', 'Togo', 'Trinidad & Tobago', 'Uganda', 'Venezuela',
#        'Viet Nam', 'Yemen'], dtype=object)

# %%
country_total_production = pd.DataFrame(
    {"country": coffee_production["total_production"].values,
     "total_coffee_production": total_production_each_country_array
    }

)

# %%
top_10_countries_production = (
    country_total_production.sort_values("total_coffee_production", ascending = False).head(10)
)

# %%
top_10_countries_production
# Out:
#       country  total_coffee_production
# 2      Brazil             1.190966e+06
# 54   Viet Nam             4.395410e+05
# 24   Colombia             3.458714e+05
# 5   Indonesia             2.451168e+05
# 30   Ethiopia             1.415429e+05
# 37      India             1.320257e+05
# 42     Mexico             1.269082e+05
# 33  Guatemala             1.134011e+05
# 36   Honduras             1.054566e+05
# 52     Uganda             9.314637e+04

# %%
import seaborn as sns

# %%
#Using Matplot Library API
fig, ax = plt.subplots(figsize = (8,8))

ax.bar(
    top_10_countries_production["country"].str[0:2], top_10_countries_production["total_coffee_production"]
)

ax.set_title("Top 10 Coffee Producing Nations 1990-2018")
ax.set_ylim(0,1300000)
ax.set_ylabel("Production (Millions 60 kg bags)")
ax.set_xlabel("Country")

sns.despine();

# %% [markdown]
# # Top 5 over time
#
# * Create a line chart with the top 5 nations over time. Make sure to include a legend! Consider converting the index to datetime64[ns].

# %%
top_10_countries_production
# Out:
#       country  total_coffee_production
# 2      Brazil             1.190966e+06
# 54   Viet Nam             4.395410e+05
# 24   Colombia             3.458714e+05
# 5   Indonesia             2.451168e+05
# 30   Ethiopia             1.415429e+05
# 37      India             1.320257e+05
# 42     Mexico             1.269082e+05
# 33  Guatemala             1.134011e+05
# 36   Honduras             1.054566e+05
# 52     Uganda             9.314637e+04

# %%
top_5_countries = top_10_countries_production.head()["country"].values

# %%
top_5_countries
# Out:
# array(['Brazil', 'Viet Nam', 'Colombia', 'Indonesia', 'Ethiopia'],
#       dtype=object)

# %%
coffee_production.head()
# Out:
#                    total_production        1990        1991        1992  \
# 0                            Angola     50.3450     79.3310     77.5200
# 1  Bolivia (Plurinational State of)    122.7770    103.5360    120.2350
# 2                            Brazil  27285.6286  27293.4934  34603.3542
# 3                           Burundi    487.3930    667.1990    620.2380
# 4                           Ecuador   1503.8150   2123.8240   1185.4800
#
#          1993       1994        1995       1996       1997        1998  ...  \
# 0     32.6080     76.802     62.1090     70.925     64.330     85.3440  ...
# 1     50.8230    116.944    142.4850    124.579    140.719    137.9850  ...
# 2  28166.9786  28192.047  18060.2022  29196.743  26148.004  36760.8533  ...
# 3    393.3540    664.143    433.9800    400.969    249.785    491.9920  ...
# 4   2069.0070   2375.766   1888.2330   1992.914   1190.663   1205.9680  ...
#
# ...

# %%
top_5_countries_yearly_data = coffee_production.query("total_production in @top_5_countries")

# %%
top_5_countries_yearly_data
# Out:
#    total_production        1990        1991        1992        1993  \
# 2            Brazil  27285.6286  27293.4934  34603.3542  28166.9786
# 5         Indonesia   7441.3830   8493.1960   5569.4780   6743.2880
# 24         Colombia  14396.0000  17980.3970  14946.8780  11422.4220
# 30         Ethiopia   2909.4510   2924.6640   1825.1710   2967.0040
# 54         Viet Nam   1310.2880   1437.8480   2340.4470   3020.2160
#
#          1994        1995       1996       1997        1998  ...        2009  \
# 2   28192.047  18060.2022  29196.743  26148.004  36760.8533  ...  43976.8120
# 5    5367.878   4573.4290   8220.584   7620.778   7295.9550  ...  11379.6699
# 24  12964.000  12938.0180  10778.850  12122.496  10867.9620  ...   8097.5861
# 30   2762.730   3165.3220   3407.442   3056.864   2927.7250  ...   6931.1990
# 54   3631.609   3970.0860   5752.481   6978.942   7051.7220  ...  17825.3453
#
#           2010        2011        2012        2013        2014        2015  \
# ...

# %%
melted_df = top_5_countries_yearly_data.melt(
    id_vars = "total_production",
    var_name = "Year",
    value_name = "Production"
)

# %%
melted_df
# Out:
#     total_production  Year  Production
# 0             Brazil  1990  27285.6286
# 1          Indonesia  1990   7441.3830
# 2           Colombia  1990  14396.0000
# 3           Ethiopia  1990   2909.4510
# 4           Viet Nam  1990   1310.2880
# ..               ...   ...         ...
# 140           Brazil  2018  62924.8836
# 141        Indonesia  2018   9417.5942
# 142         Colombia  2018  13857.9620
# 143         Ethiopia  2018   7776.2234
# 144         Viet Nam  2018  31174.0742
#
# [145 rows x 3 columns]

# %%
top_5_countries_and_years = melted_df.pivot_table(
    index = "Year",
    columns = "total_production",
    values = "Production"
)

# %%
top_5_countries_and_years
# Out:
# total_production      Brazil    Colombia   Ethiopia   Indonesia    Viet Nam
# Year
# 1990              27285.6286  14396.0000  2909.4510   7441.3830   1310.2880
# 1991              27293.4934  17980.3970  2924.6640   8493.1960   1437.8480
# 1992              34603.3542  14946.8780  1825.1710   5569.4780   2340.4470
# 1993              28166.9786  11422.4220  2967.0040   6743.2880   3020.2160
# 1994              28192.0470  12964.0000  2762.7300   5367.8780   3631.6090
# 1995              18060.2022  12938.0180  3165.3220   4573.4290   3970.0860
# 1996              29196.7430  10778.8500  3407.4420   8220.5840   5752.4810
# 1997              26148.0040  12122.4960  3056.8640   7620.7780   6978.9420
# 1998              36760.8533  10867.9620  2927.7250   7295.9550   7051.7220
# 1999              47577.8065   9512.2459  3784.0510   6557.0662  11630.9138
# 2000              31310.3530  10519.3520  3115.1490   6987.2397  14841.3090
# ...

# %%
#Using Matplot Library
fig, ax = plt.subplots()

ax.plot(top_5_countries_and_years)

ax.set_title("Top 5 Nations Production Over Time 1990-2018")
ax.set_ylabel("Production (Millions 60 kg bags)")
ax.set_xlabel("Year")

ax.set_xticks(top_5_countries_and_years.index[2::4])

ax.legend(top_5_countries_and_years.columns)

sns.despine();

# %% [markdown]
# # COMPOSITION OVER TIME
#
# Our client is interested in looking at how Brazil's share of global coffee production has changed over time.
#
# Build a plot that global total production as well as Brazil's contribution to global production over time.

# %%
coffee_production.head()
# Out:
#                    total_production        1990        1991        1992  \
# 0                            Angola     50.3450     79.3310     77.5200
# 1  Bolivia (Plurinational State of)    122.7770    103.5360    120.2350
# 2                            Brazil  27285.6286  27293.4934  34603.3542
# 3                           Burundi    487.3930    667.1990    620.2380
# 4                           Ecuador   1503.8150   2123.8240   1185.4800
#
#          1993       1994        1995       1996       1997        1998  ...  \
# 0     32.6080     76.802     62.1090     70.925     64.330     85.3440  ...
# 1     50.8230    116.944    142.4850    124.579    140.719    137.9850  ...
# 2  28166.9786  28192.047  18060.2022  29196.743  26148.004  36760.8533  ...
# 3    393.3540    664.143    433.9800    400.969    249.785    491.9920  ...
# 4   2069.0070   2375.766   1888.2330   1992.914   1190.663   1205.9680  ...
#
# ...

# %%
coffee_production.iloc[:,1:].head()
# Out:
#          1990        1991        1992        1993       1994        1995  \
# 0     50.3450     79.3310     77.5200     32.6080     76.802     62.1090
# 1    122.7770    103.5360    120.2350     50.8230    116.944    142.4850
# 2  27285.6286  27293.4934  34603.3542  28166.9786  28192.047  18060.2022
# 3    487.3930    667.1990    620.2380    393.3540    664.143    433.9800
# 4   1503.8150   2123.8240   1185.4800   2069.0070   2375.766   1888.2330
#
#         1996       1997        1998        1999  ...        2009        2010  \
# 0     70.925     64.330     85.3440     54.9390  ...     13.4200     34.9700
# 1    124.579    140.719    137.9850    157.7020  ...    128.4751    117.2249
# 2  29196.743  26148.004  36760.8533  47577.8065  ...  43976.8120  55428.4102
# 3    400.969    249.785    491.9920    350.5500  ...    111.6130    352.9776
# 4   1992.914   1190.663   1205.9680   1197.6832  ...    813.2849    853.9798
#
# ...

# %%
coffee_production.iloc[:,1:].columns
# Out:
# Index(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018'],
#       dtype='object')

# %%
countries_df_melted = pd.melt(
    coffee_production, 
    id_vars = "total_production", value_vars = coffee_production.iloc[:,1:].columns,
    var_name = "Year", value_name = "Production"
)

# %%
countries_df_melted
# Out:
#                       total_production  Year  Production
# 0                               Angola  1990     50.3450
# 1     Bolivia (Plurinational State of)  1990    122.7770
# 2                               Brazil  1990  27285.6286
# 3                              Burundi  1990    487.3930
# 4                              Ecuador  1990   1503.8150
# ...                                ...   ...         ...
# 1619                 Trinidad & Tobago  2018     12.3647
# 1620                            Uganda  2018   4703.9640
# 1621                         Venezuela  2018    525.2602
# 1622                          Viet Nam  2018  31174.0742
# 1623                             Yemen  2018    106.0735
#
# [1624 rows x 3 columns]

# %%
countries_df_melted.query("total_production != 'Brazil'").head()
# Out:
#                    total_production  Year  Production
# 0                            Angola  1990      50.345
# 1  Bolivia (Plurinational State of)  1990     122.777
# 3                           Burundi  1990     487.393
# 4                           Ecuador  1990    1503.815
# 5                         Indonesia  1990    7441.383

# %%
rest_of_world_yearly_production = (
    countries_df_melted.query("total_production != 'Brazil'")
    .groupby("Year")
    .agg({"Production": "sum"})
)

# %%
rest_of_world_yearly_production.head()
# Out:
#       Production
# Year
# 1990   65944.431
# 1991   73973.191
# 1992   63922.545
# 1993   63597.643
# 1994   65121.147

# %%
brazil_yearly_production = countries_df_melted.query("total_production == 'Brazil'").pivot_table(
    index = "Year",
    values = "Production",
)

# %%
brazil_yearly_production.head()
# Out:
#       Production
# Year
# 1990  27285.6286
# 1991  27293.4934
# 1992  34603.3542
# 1993  28166.9786
# 1994  28192.0470

# %%
brazil_vs_rest_of_world_year_comparison = brazil_yearly_production.merge(
    rest_of_world_yearly_production,
    how = "left",
    left_on = "Year",
    right_on = "Year"
).rename(columns = {"Production_x": "Brazil", "Production_y": "Rest of World"})

# %%
brazil_vs_rest_of_world_year_comparison.head()
# Out:
#           Brazil  Rest of World
# Year
# 1990  27285.6286      65944.431
# 1991  27293.4934      73973.191
# 1992  34603.3542      63922.545
# 1993  28166.9786      63597.643
# 1994  28192.0470      65121.147

# %%
fig, ax = plt.subplots()

ax.stackplot(
    
    brazil_vs_rest_of_world_year_comparison.index,
    brazil_vs_rest_of_world_year_comparison["Brazil"],
    brazil_vs_rest_of_world_year_comparison["Rest of World"]
)

ax.set_title("Brazil's Share of Global Coffee Production 1990 - 2018", fontsize = 12)
#ax.set_ylim(0,200000)
ax.set_ylabel("Production (Millions 60 kg Bags)")
ax.set_xlabel("Year")

ax.legend(brazil_vs_rest_of_world_year_comparison.columns)

ax.set_xticks(brazil_vs_rest_of_world_year_comparison.index[2::4])

sns.despine();

# %% [markdown]
# ## PRODUCTION RELATIONSHIPS
#
# We want to explore how Brazil compares to its competitors in terms of production. Build a scatterplot  comparing Brazil Vs. VietNam Production and one comparing Brazil to Venezuela.

# %%
coffee_production.head()
# Out:
#                    total_production        1990        1991        1992  \
# 0                            Angola     50.3450     79.3310     77.5200
# 1  Bolivia (Plurinational State of)    122.7770    103.5360    120.2350
# 2                            Brazil  27285.6286  27293.4934  34603.3542
# 3                           Burundi    487.3930    667.1990    620.2380
# 4                           Ecuador   1503.8150   2123.8240   1185.4800
#
#          1993       1994        1995       1996       1997        1998  ...  \
# 0     32.6080     76.802     62.1090     70.925     64.330     85.3440  ...
# 1     50.8230    116.944    142.4850    124.579    140.719    137.9850  ...
# 2  28166.9786  28192.047  18060.2022  29196.743  26148.004  36760.8533  ...
# 3    393.3540    664.143    433.9800    400.969    249.785    491.9920  ...
# 4   2069.0070   2375.766   1888.2330   1992.914   1190.663   1205.9680  ...
#
# ...

# %%
three_countries_df = coffee_production.loc[
    (coffee_production["total_production"] == "Brazil") | (coffee_production["total_production"] == "Viet Nam")
    | (coffee_production["total_production"] == "Venezuela")
]

# %%
three_countries_df
# Out:
#    total_production        1990        1991        1992        1993  \
# 2            Brazil  27285.6286  27293.4934  34603.3542  28166.9786
# 53        Venezuela   1122.4770    940.7040   1215.2980   1332.8810
# 54         Viet Nam   1310.2880   1437.8480   2340.4470   3020.2160
#
#          1994        1995       1996       1997        1998  ...        2009  \
# 2   28192.047  18060.2022  29196.743  26148.004  36760.8533  ...  43976.8120
# 53    988.996   1466.5540   1206.162    951.285   1597.2790  ...   1213.7061
# 54   3631.609   3970.0860   5752.481   6978.942   7051.7220  ...  17825.3453
#
#           2010        2011        2012        2013        2014        2015  \
# 2   55428.4102  48591.8289  55418.0012  54688.9664  53304.7669  52870.5876
# 53   1202.1338    902.0717    952.4201    803.7688    650.3983    500.1259
# 54  19999.9999  26499.6111  23402.1057  27609.7814  26499.8404  28736.5941
#
#           2016        2017        2018
# ...

# %%
year_array = three_countries_df.columns[1:]

# %%
three_countries_melted_df = pd.melt(
    three_countries_df,
    id_vars = "total_production",
    value_vars = year_array,
    var_name = "year",
    value_name = "production"

).rename(columns = {"total_production": "country"})

# %%
three_countries_piv_table = three_countries_melted_df.pivot_table(
    index = "year",
    columns = "country",
    values = "production"
)

# %%
three_countries_piv_table
# Out:
# country      Brazil  Venezuela    Viet Nam
# year
# 1990     27285.6286  1122.4770   1310.2880
# 1991     27293.4934   940.7040   1437.8480
# 1992     34603.3542  1215.2980   2340.4470
# 1993     28166.9786  1332.8810   3020.2160
# 1994     28192.0470   988.9960   3631.6090
# 1995     18060.2022  1466.5540   3970.0860
# 1996     29196.7430  1206.1620   5752.4810
# 1997     26148.0040   951.2850   6978.9420
# 1998     36760.8533  1597.2790   7051.7220
# 1999     47577.8065  1366.8350  11630.9138
# 2000     31310.3530  1449.9240  14841.3090
# 2001     31365.0955  1264.6130  13093.2440
# 2002     48351.6340  1483.5896  11573.9350
# 2003     28873.4093  1420.5247  15337.3520
# 2004     39281.1457  1326.5336  14370.4530
# 2005     32932.9797  1506.3009  13841.8363
# 2006     48431.7338  1570.8961  19339.7501
# 2007     38911.4571  1520.4505  16405.0988
# 2008     51490.5177   932.4219  18438.1201
# 2009     43976.8120  1213.7061  17825.3453
# 2010     55428.4102  1202.1338  19999.9999
# ...

# %%
fig, ax = plt.subplots()

ax.scatter(three_countries_piv_table["Brazil"], three_countries_piv_table["Viet Nam"], alpha = 0.8)

ax.set_title("Vietnam and Brazil Production Trend Up Together")
ax.set_xlabel("Brazil Production")
ax.set_ylabel("Viet Nam Production (Millions 60 kg bags)")
ax.set_ylim(0,34000)
sns.despine();

# %%
fig, ax = plt.subplots()

ax.scatter(three_countries_piv_table["Brazil"], three_countries_piv_table["Venezuela"], alpha = 0.8)

ax.set_title("Venezuela Production Declines as Brazil Expands")
ax.set_xlabel("Brazil Production (Millions 60 kg bags)")
ax.set_ylabel("Venezuela Production (Millions 60 kg bags)")
ax.set_ylim(0,1800)
sns.despine();

# %% [markdown]
# # COMPOSITION OF COFFEE PRODUCTION
#
# * Create a Pie chart with the top 5 producers, as well as the sum for the rest of countries.
#
# * Finally, create two donut charts, one representing Brazil's share of global production in 1990, and one for Brazil's share in 2018.

# %%
coffee_production.head()
# Out:
#                    total_production        1990        1991        1992  \
# 0                            Angola     50.3450     79.3310     77.5200
# 1  Bolivia (Plurinational State of)    122.7770    103.5360    120.2350
# 2                            Brazil  27285.6286  27293.4934  34603.3542
# 3                           Burundi    487.3930    667.1990    620.2380
# 4                           Ecuador   1503.8150   2123.8240   1185.4800
#
#          1993       1994        1995       1996       1997        1998  ...  \
# 0     32.6080     76.802     62.1090     70.925     64.330     85.3440  ...
# 1     50.8230    116.944    142.4850    124.579    140.719    137.9850  ...
# 2  28166.9786  28192.047  18060.2022  29196.743  26148.004  36760.8533  ...
# 3    393.3540    664.143    433.9800    400.969    249.785    491.9920  ...
# 4   2069.0070   2375.766   1888.2330   1992.914   1190.663   1205.9680  ...
#
# ...

# %%
all_countries = coffee_production["total_production"].unique()

# %%
all_countries_data_yearly = coffee_production.iloc[:,1:]

# %%
all_countries_data_yearly.head()
# Out:
#          1990        1991        1992        1993       1994        1995  \
# 0     50.3450     79.3310     77.5200     32.6080     76.802     62.1090
# 1    122.7770    103.5360    120.2350     50.8230    116.944    142.4850
# 2  27285.6286  27293.4934  34603.3542  28166.9786  28192.047  18060.2022
# 3    487.3930    667.1990    620.2380    393.3540    664.143    433.9800
# 4   1503.8150   2123.8240   1185.4800   2069.0070   2375.766   1888.2330
#
#         1996       1997        1998        1999  ...        2009        2010  \
# 0     70.925     64.330     85.3440     54.9390  ...     13.4200     34.9700
# 1    124.579    140.719    137.9850    157.7020  ...    128.4751    117.2249
# 2  29196.743  26148.004  36760.8533  47577.8065  ...  43976.8120  55428.4102
# 3    400.969    249.785    491.9920    350.5500  ...    111.6130    352.9776
# 4   1992.914   1190.663   1205.9680   1197.6832  ...    813.2849    853.9798
#
# ...

# %%
all_countries_data_yearly.shape
# Out:
# (56, 29)

# %%
array_with_countries_total_production = []

for row_num in range(0,all_countries_data_yearly.shape[0],1):
    total_result = 0.0
    
    for col_num in range(0,all_countries_data_yearly.shape[1],1):
        
        total_result = total_result + float(all_countries_data_yearly.iloc[row_num, col_num])
    
    array_with_countries_total_production.append(total_result)

# %%
pd.DataFrame(
    {"country": all_countries,
     "total_coffee_production": array_with_countries_total_production
    }
).head()
# Out:
#                             country  total_coffee_production
# 0                            Angola             1.312425e+03
# 1  Bolivia (Plurinational State of)             3.368238e+03
# 2                            Brazil             1.190966e+06
# 3                           Burundi             1.015500e+04
# 4                           Ecuador             3.121863e+04

# %%
countries_total_produce = pd.DataFrame(
    {"country": all_countries,
     "total_coffee_production": array_with_countries_total_production
    }
).sort_values("total_coffee_production", ascending = False)

# %%
top_5_producers = countries_total_produce.head()

# %%
top_5_producers
# Out:
#       country  total_coffee_production
# 2      Brazil             1.190966e+06
# 54   Viet Nam             4.395410e+05
# 24   Colombia             3.458714e+05
# 5   Indonesia             2.451168e+05
# 30   Ethiopia             1.415429e+05

# %%
countries_total_produce.iloc[5:].head()
# Out:
#       country  total_coffee_production
# 37      India              132025.6810
# 42     Mexico              126908.2467
# 33  Guatemala              113401.0702
# 36   Honduras              105456.5888
# 52     Uganda               93146.3690

# %%
rest_of_countries_total = countries_total_produce.iloc[5:]["total_coffee_production"].sum()

# %%
rest_of_countries_total
# Out:
# np.float64(1225391.5436)

# %%
not_top_5_countries = pd.DataFrame(
    {"country": ["rest_of_countries"], "total_coffee_production": [rest_of_countries_total]}
)

# %%
not_top_5_countries
# Out:
#              country  total_coffee_production
# 0  rest_of_countries             1.225392e+06

# %%
top_5_vs_rest = pd.concat([not_top_5_countries, top_5_producers])

# %%
top_5_vs_rest
# Out:
#               country  total_coffee_production
# 0   rest_of_countries             1.225392e+06
# 2              Brazil             1.190966e+06
# 54           Viet Nam             4.395410e+05
# 24           Colombia             3.458714e+05
# 5           Indonesia             2.451168e+05
# 30           Ethiopia             1.415429e+05

# %%
fig, ax = plt.subplots()
ax.pie(
    x = top_5_vs_rest["total_coffee_production"],
    startangle = 90,
    labels = top_5_vs_rest["country"],
    autopct = "%.0f%%"
)

ax.set_title("Share of Top 5 vs Rest of Countries");

# %%
data_1990_2018 = coffee_production.loc[:,["total_production", "1990", "2018"]]

# %%
data_1990_2018.head()
# Out:
#                    total_production        1990        2018
# 0                            Angola     50.3450     40.3874
# 1  Bolivia (Plurinational State of)    122.7770     82.5687
# 2                            Brazil  27285.6286  62924.8836
# 3                           Burundi    487.3930    178.4206
# 4                           Ecuador   1503.8150    601.0001

# %%
brazil_1990_2018_df = data_1990_2018.query("total_production == 'Brazil'")

# %%
brazil_1990_2018_df
# Out:
#   total_production        1990        2018
# 2           Brazil  27285.6286  62924.8836

# %%
rest_of_world_1990_total = data_1990_2018.loc[data_1990_2018["total_production"]!='Brazil']["1990"].sum()

# %%
rest_of_world_2018_total = data_1990_2018.loc[data_1990_2018["total_production"]!='Brazil']["1990"].sum()

# %%
rest_of_world_df = pd.DataFrame(
    {"total_production": ["Rest of World"], "1990": [rest_of_world_1990_total], "2018": [rest_of_world_2018_total]}
)

# %%
rest_of_world_df
# Out:
#   total_production       1990       2018
# 0    Rest of World  65944.431  65944.431

# %%
brazil_vs_rest_of_world_1990_2018 = (
    
    pd.concat([brazil_1990_2018_df, rest_of_world_df])
    .rename(columns = {
        "total_production": "country", "1990": "total_production_1990", "2018": "total_production_2018"
    })
)

# %%
brazil_vs_rest_of_world_1990_2018
# Out:
#          country  total_production_1990  total_production_2018
# 2         Brazil             27285.6286             62924.8836
# 0  Rest of World             65944.4310             65944.4310

# %%
fig, ax = plt.subplots()

ax.pie(
    x = brazil_vs_rest_of_world_1990_2018["total_production_1990"],
    startangle = 90,
    labels = brazil_vs_rest_of_world_1990_2018["country"],
    autopct = "%.0f%%"
)

donut_hole = plt.Circle((0,0), 0.70, fc = "white")
fig = plt.gcf()

fig.gca().add_artist(donut_hole)

ax.set_title("Share of Global Production Brazil vs Rest of World 1990");

# %%
fig, ax = plt.subplots()

ax.pie(
    x = brazil_vs_rest_of_world_1990_2018["total_production_2018"],
    startangle = 90,
    labels = brazil_vs_rest_of_world_1990_2018["country"],
    autopct = "%.0f%%"
)

donut_hole = plt.Circle((0,0), 0.70, fc = "white")
fig = plt.gcf()

fig.gca().add_artist(donut_hole)

ax.set_title("Share of Global Production Brazil vs Rest of World 2018");

# %% [markdown]
# # Coffee Consumption Vs. Prices
#
# Compare coffee prices with coffee consumption in the following countries.
#
# Is there a relationship between coffee consumption and the price these countries pay?
#
# Plot a dual axis bar chart of price vs consumption totals for these countries.

# %%
consumption = pd.read_csv("/Users/huzaifamalik/Downloads/Python for Data Analytics/Data Visualization with Matplotlib & Seaborn/Data Viz with Matplotlib & Seaborn/Data/coffee/imports.csv")

# %%
consumption
# Out:
#                    imports         1990         1991         1992  \
# 0                  Austria  1880.000000  2058.000000  2206.000000
# 1                  Belgium          NaN          NaN          NaN
# 2       Belgium/Luxembourg  2015.000000  1746.000000  1828.000000
# 3                 Bulgaria   268.000000   200.000000   182.000000
# 4                  Croatia          NaN          NaN   168.000000
# ..                     ...          ...          ...          ...
# 142          South America   668.199002   748.614998   950.163006
# 143              Argentina   508.360998   577.463999   697.761000
# 144                  Chile   115.640002   133.958001   203.930001
# 145               Suriname     1.937000     7.002000     2.928004
# 146                Uruguay    42.261001    30.190998    45.544001
#
#             1993         1994         1995         1996         1997  \
# 0    1836.000000  1417.000000  1231.000000  1210.000000  1294.000000
# ...

# %%
consumption["imports"].nunique()
# Out:
# 147

# %%
consumption_filtered_df = consumption.query("imports in @countries_in_price_df")

# %%
consumption_filtered_df
# Out:
#            imports     1990     1991     1992     1993     1994     1995  \
# 0          Austria   1880.0   2058.0   2206.0   1836.0   1417.0   1231.0
# 5           Cyprus     50.0     54.0     41.0     77.0     52.0     44.0
# 7          Denmark    959.0    983.0   1062.0    994.0   1033.0    877.0
# 9          Finland   1095.0   1033.0   1055.0   1301.0   1361.0    769.0
# 10          France   6301.0   6553.0   6612.0   6334.0   6369.0   6214.0
# 11         Germany  13671.0  13229.0  13789.0  14107.0  13583.0  12852.0
# 15           Italy   5242.0   4630.0   4595.0   5594.0   5554.0   5388.0
# 20     Netherlands   3128.0   3121.0   3205.0   2804.0   2800.0   2910.0
# 22        Portugal    552.0    557.0    591.0    666.0    664.0    633.0
# 26           Spain   3053.0   2970.0   3414.0   2813.0   3028.0   3146.0
# 27          Sweden   1767.0   1717.0   1772.0   1757.0   1893.0   1420.0
# 29           Japan   5330.0   5510.0   5326.0   5691.0   6217.0   5489.0
# ...

# %%
import_years_array = consumption.iloc[:,1:].columns

# %%
import_years_array
# Out:
# Index(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018'],
#       dtype='object')

# %%
consumption_melted_filtered_df = pd.melt(
    consumption_filtered_df,
    id_vars = "imports",
    value_vars = import_years_array,
    var_name = "year",
    value_name = "imports_yearly"
)

# %%
consumption_melted_filtered_df
# Out:
#          imports  year  imports_yearly
# 0        Austria  1990     1880.000000
# 1         Cyprus  1990       50.000000
# 2        Denmark  1990      959.000000
# 3        Finland  1990     1095.000000
# 4         France  1990     6301.000000
# ..           ...   ...             ...
# 372     Portugal  2018             NaN
# 373        Spain  2018             NaN
# 374       Sweden  2018             NaN
# 375        Japan  2018     7539.981823
# 376       Norway  2018      743.340422
#
# [377 rows x 3 columns]

# %%
avg_consumption_df = consumption_melted_filtered_df.groupby("imports").agg({"imports_yearly": "mean"})

# %%
avg_consumption_df = avg_consumption_df.rename(columns = {"imports_yearly": "avg_imports"})

# %%
avg_consumption_df
# Out:
#                  avg_imports
# imports
#    Austria       1551.083333
#    Cyprus          63.791667
#    Denmark        991.791667
#    Finland       1157.541667
#    France        6512.458333
#    Germany      16357.666667
#    Italy         6696.958333
#    Netherlands   2928.125000
#    Portugal       810.791667
#    Spain         4046.291667
#    Sweden        1620.625000
# Japan            6862.275235
# Norway            739.770359

# %%
prices = pd.read_csv("/Users/huzaifamalik/Downloads/Python for Data Analytics/Data Visualization with Matplotlib & Seaborn/Data Viz with Matplotlib & Seaborn/Data/coffee/retail-prices.csv")

# %%
prices
# Out:
#      retail_prices       1990       1991       1992       1993       1994  \
# 0          Austria  10.816777  10.088300  11.015453  10.971302  10.110375
# 1           Cyprus   6.247241   6.181015   6.335541   5.739514   7.019868
# 2          Denmark   8.410596   8.101545   8.366446   7.682119   9.823400
# 3          Finland   6.578366   6.004415   5.430464   4.282561   6.026490
# 4           France   8.233996   7.571744   5.099338   4.481236   5.298013
# 5          Germany   8.807947   8.476821   8.830022   7.991170   9.227373
# 6            Italy  11.721854  12.406181  12.935982  10.132450  10.331126
# 7      Netherlands   6.688742   6.512141   6.909492   6.181015   7.196468
# 8         Portugal   9.094923   9.426049  10.927152   9.426049   9.668874
# 9            Spain   7.991170   7.726269   7.726269   6.158940   6.092715
# 10          Sweden   7.571744   7.262693   6.865342   5.849890   8.366446
# 11  United Kingdom  23.289183  22.980132  22.273731  18.631347  25.077263
# ...

# %%
countries_in_price_df = prices["retail_prices"].unique()

# %%
countries_in_price_df
# Out:
# array(['   Austria', '   Cyprus', '   Denmark', '   Finland', '   France',
#        '   Germany', '   Italy', '   Netherlands', '   Portugal',
#        '   Spain', '   Sweden', 'United Kingdom', 'Japan', 'Norway'],
#       dtype=object)

# %%
prices.iloc[:,1:]
# Out:
#          1990       1991       1992       1993       1994       1995  \
# 0   10.816777  10.088300  11.015453  10.971302  10.110375  11.434879
# 1    6.247241   6.181015   6.335541   5.739514   7.019868   9.403974
# 2    8.410596   8.101545   8.366446   7.682119   9.823400  12.295806
# 3    6.578366   6.004415   5.430464   4.282561   6.026490   8.763797
# 4    8.233996   7.571744   5.099338   4.481236   5.298013   8.145695
# 5    8.807947   8.476821   8.830022   7.991170   9.227373  11.081678
# 6   11.721854  12.406181  12.935982  10.132450  10.331126  12.582781
# 7    6.688742   6.512141   6.909492   6.181015   7.196468   8.896247
# 8    9.094923   9.426049  10.927152   9.426049   9.668874  13.774834
# 9    7.991170   7.726269   7.726269   6.158940   6.092715   9.823400
# 10   7.571744   7.262693   6.865342   5.849890   8.366446  10.706402
# 11  23.289183  22.980132  22.273731  18.631347  25.077263  30.441501
# 12  22.649007  26.225166  27.858720  32.163355  32.428256  39.116998
# ...

# %%
prices.iloc[:,1:].shape
# Out:
# (14, 29)

# %%
prices.iloc[:,1:].iloc[0,1]
# Out:
# np.float64(10.08830022075055)

# %%
retail_prices_avg_array = []

for row_num in range(0,prices.iloc[:,1:].shape[0],1):
    total = 0.0
    
    for col_num in range(0,prices.iloc[:,1:].shape[1],1):
        total = total + prices.iloc[:,1:].iloc[row_num, col_num]
        
    avg_value = total/(col_num + 1)
    
    retail_prices_avg_array.append(float(avg_value))

# %%
retail_prices_avg_array
# Out:
# [11.571134962320162,
#  10.437695059754889,
#  10.494024510923344,
#  7.211692167161451,
#  6.850879196163507,
#  9.515109994671535,
#  14.199588947248227,
#  8.931262845398491,
#  10.921062647484202,
#  8.029991626703204,
#  8.054350308289564,
#  32.93902717515413,
#  21.472939027175155,
#  9.40930197153079]

# %%
avg_price_df = pd.DataFrame(
    {"country": countries_in_price_df, "avg_price": retail_prices_avg_array}
)

# %%
avg_price_df
# Out:
#            country  avg_price
# 0          Austria  11.571135
# 1           Cyprus  10.437695
# 2          Denmark  10.494025
# 3          Finland   7.211692
# 4           France   6.850879
# 5          Germany   9.515110
# 6            Italy  14.199589
# 7      Netherlands   8.931263
# 8         Portugal  10.921063
# 9            Spain   8.029992
# 10          Sweden   8.054350
# 11  United Kingdom  32.939027
# 12           Japan  21.472939
# 13          Norway   9.409302

# %%
country_avg_consumption_and_price = avg_price_df.merge(
    avg_consumption_df,
    how = "inner",
    left_on = "country",
    right_on = "imports"
).sort_values("avg_imports", ascending = False)

# %%
country_avg_consumption_and_price
# Out:
#            country  avg_price   avg_imports
# 5          Germany   9.515110  16357.666667
# 11           Japan  21.472939   6862.275235
# 6            Italy  14.199589   6696.958333
# 4           France   6.850879   6512.458333
# 9            Spain   8.029992   4046.291667
# 7      Netherlands   8.931263   2928.125000
# 10          Sweden   8.054350   1620.625000
# 0          Austria  11.571135   1551.083333
# 3          Finland   7.211692   1157.541667
# 2          Denmark  10.494025    991.791667
# 8         Portugal  10.921063    810.791667
# 12          Norway   9.409302    739.770359
# 1           Cyprus  10.437695     63.791667

# %%
fig, ax = plt.subplots(figsize=(12, 6))
x = np.arange(len(country_avg_consumption_and_price))  # numeric positions
width = 0.4  # width of each bar

# Primary y-axis: Average Imports
ax.bar(x - width/2, country_avg_consumption_and_price["avg_imports"], 
       width=width, label="Average Imports")
ax.set_ylabel("Average Consumption (k 60 kg bags)", fontsize = 10)

# Secondary y-axis: Average Price
ax2 = ax.twinx()
ax2.bar(x + width/2, country_avg_consumption_and_price["avg_price"], 
        width=width, label="Average Price", color="orange")
ax2.set_ylabel("Average Price Paid Per Bag (USD)", fontsize = 10)

ax.set_xticks(x)
ax.set_xticklabels(country_avg_consumption_and_price["country"], fontsize=8, rotation=0)
ax.tick_params(axis='y', labelsize=9)
ax2.tick_params(axis='y', labelsize=9)

fig.legend(bbox_to_anchor = (0.9,0.88))
fig.suptitle("Prices Paid vs Consumption of Select Importing Nations")
plt.tight_layout()
plt.show();

# %%
coffee_production.head()
# Out:
#                    total_production        1990        1991        1992  \
# 0                            Angola     50.3450     79.3310     77.5200
# 1  Bolivia (Plurinational State of)    122.7770    103.5360    120.2350
# 2                            Brazil  27285.6286  27293.4934  34603.3542
# 3                           Burundi    487.3930    667.1990    620.2380
# 4                           Ecuador   1503.8150   2123.8240   1185.4800
#
#          1993       1994        1995       1996       1997        1998  ...  \
# 0     32.6080     76.802     62.1090     70.925     64.330     85.3440  ...
# 1     50.8230    116.944    142.4850    124.579    140.719    137.9850  ...
# 2  28166.9786  28192.047  18060.2022  29196.743  26148.004  36760.8533  ...
# 3    393.3540    664.143    433.9800    400.969    249.785    491.9920  ...
# 4   2069.0070   2375.766   1888.2330   1992.914   1190.663   1205.9680  ...
#
# ...

# %%
pd.melt(
    coffee_production,
    id_vars = "total_production",
    value_vars = coffee_production.iloc[:,1:],
    var_name = "year",
    value_name = "production_amount"
).rename(columns = {"total_production": "country"})
# Out:
#                                country  year  production_amount
# 0                               Angola  1990            50.3450
# 1     Bolivia (Plurinational State of)  1990           122.7770
# 2                               Brazil  1990         27285.6286
# 3                              Burundi  1990           487.3930
# 4                              Ecuador  1990          1503.8150
# ...                                ...   ...                ...
# 1619                 Trinidad & Tobago  2018            12.3647
# 1620                            Uganda  2018          4703.9640
# 1621                         Venezuela  2018           525.2602
# 1622                          Viet Nam  2018         31174.0742
# 1623                             Yemen  2018           106.0735
#
# [1624 rows x 3 columns]

# %%
abc_dataframe = (
    pd.melt(
        coffee_production, 
        id_vars = "total_production",
        value_vars = coffee_production.iloc[:,1:],
        var_name = "year",
        value_name = "production_amount"
    )
    .rename(columns = {"total_production": "country"})
    .groupby("country").agg({"production_amount": "sum"})
    .sort_values("production_amount", ascending = False)
)

# %%
abc_dataframe.head()
# Out:
#            production_amount
# country
# Brazil          1.190966e+06
# Viet Nam        4.395410e+05
# Colombia        3.458714e+05
# Indonesia       2.451168e+05
# Ethiopia        1.415429e+05

# %%
float(abc_dataframe.iloc[5:].values.sum())
# Out:
# 1225391.5436

# %%
top_5_and_rest_df_for_bar = pd.concat(
    [abc_dataframe.reset_index().head(),
     pd.DataFrame(
         {"country": ["Rest of World"], "production_amount": [float(abc_dataframe.iloc[5:].values.sum())]}
     )
    ]
)

# %%
top_5_and_rest_df_for_bar
# Out:
#          country  production_amount
# 0         Brazil       1.190966e+06
# 1       Viet Nam       4.395410e+05
# 2       Colombia       3.458714e+05
# 3      Indonesia       2.451168e+05
# 4       Ethiopia       1.415429e+05
# 0  Rest of World       1.225392e+06

# %%
#Flip Brazil and Rest of World
top_5_and_rest_df_for_bar = top_5_and_rest_df_for_bar.iloc[::-1]

# %%
top_5_and_rest_df_for_bar
# Out:
#          country  production_amount
# 0  Rest of World       1.225392e+06
# 4       Ethiopia       1.415429e+05
# 3      Indonesia       2.451168e+05
# 2       Colombia       3.458714e+05
# 1       Viet Nam       4.395410e+05
# 0         Brazil       1.190966e+06

# %%
abc_dataframe.head().index
# Out:
# Index(['Brazil', 'Viet Nam', 'Colombia', 'Indonesia', 'Ethiopia'], dtype='object', name='country')

# %%
coffee_data_of_countries_2018 = coffee_production.loc[:,["total_production", "2018"]]

# %%
coffee_data_of_countries_2018.head()
# Out:
#                    total_production        2018
# 0                            Angola     40.3874
# 1  Bolivia (Plurinational State of)     82.5687
# 2                            Brazil  62924.8836
# 3                           Burundi    178.4206
# 4                           Ecuador    601.0001

# %%
rest_of_world_total_production_2018 = float(
    (
        coffee_data_of_countries_2018
        .query("total_production not in @abc_dataframe.head().index")["2018"]
        .values.sum()
    )
)

# %%
rest_of_world_total_production_2018
# Out:
# 45786.00029999999

# %%
rest_of_world_total_production_2018_df = pd.DataFrame(
    {"country": ["Rest of World"], "production_amount": [rest_of_world_total_production_2018]}
)

# %%
rest_of_world_total_production_2018_df
# Out:
#          country  production_amount
# 0  Rest of World         45786.0003

# %%
top_5_countries_production_2018 = coffee_data_of_countries_2018.loc[
    coffee_data_of_countries_2018["total_production"].isin(abc_dataframe.head().index)
].rename(columns = {"total_production": "country", "2018": "production_amount"})

# %%
top_5_countries_production_2018
# Out:
#       country  production_amount
# 2      Brazil         62924.8836
# 5   Indonesia          9417.5942
# 24   Colombia         13857.9620
# 30   Ethiopia          7776.2234
# 54   Viet Nam         31174.0742

# %%
top_5_vs_rest_2018 = pd.concat([top_5_countries_production_2018, rest_of_world_total_production_2018_df])

# %%
top_5_vs_rest_2018
# Out:
#           country  production_amount
# 2          Brazil         62924.8836
# 5       Indonesia          9417.5942
# 24       Colombia         13857.9620
# 30       Ethiopia          7776.2234
# 54       Viet Nam         31174.0742
# 0   Rest of World         45786.0003

# %%
#Create a Meshgrid Layout to combine our findings into a single report.
#We want two donut charts representing Brazil's production share in 1990 and 2018 in top third of the figure.
#Stackplot comparing Brazil to the rest of the world in the center of the figure.
#In the bottom third a bar chart showing the total production of our top 5 countries, as well as a bar for other. 
#Also include a pie chart showing the composition of the same data plotted in the bar chart.

#Look up the country colors for our top 5 countries and color them accordingly. 
#For 'other' category, color these grey.

#Consider setting rcParams to turn top and right borders off.
#Save the report out as an image.

# %%
import matplotlib.gridspec as gridspec

plt.rc('axes.spines', right = False, top = False)

flag_colors = ["#808080", "#0F47AF", "#FF0000", "#FFD700", "#DA251D", "#009739"]

fig = plt.figure(figsize = (8,8))
gs = gridspec.GridSpec(ncols = 6, nrows = 6)

ax1 = fig.add_subplot(gs[0:2, 0:2])
ax2 = fig.add_subplot(gs[0:2, 2:4])
ax3 = fig.add_subplot(gs[0:2:, 4:6])
ax4 = fig.add_subplot(gs[2:4, 0:6])
ax5 = fig.add_subplot(gs[4:6, 0:3])
ax6 = fig.add_subplot(gs[4:6, 3:6])

#First Donut Chart 1990 Data
ax2.pie(
    x = brazil_vs_rest_of_world_1990_2018["total_production_1990"],
    startangle = 340,
    labels = ["", ""],
    colors = ["#009739", "#FFFFFF"],
)

donut_hole = plt.Circle((0,0), 0.70, fc = "white")
fig = plt.gcf()

ax2.add_artist(donut_hole)

ax2.set_title("Brazil % Global Production 1990", fontsize = 9, fontstyle = 'italic')
ax2.text(0, 0, "29%", ha='center', va='center', fontsize=16, fontweight='bold', color="black")

#Second Donut Chart 2018 Data
ax3.pie(
    x = brazil_vs_rest_of_world_1990_2018["total_production_2018"],
    startangle = 280,
    labels = ["", ""],
    colors = ["#009739", "#FFFFFF"],
)

donut_hole = plt.Circle((0,0), 0.70, fc = "white")
fig = plt.gcf()


ax3.add_artist(donut_hole)

ax3.set_title("Brazil % Global Production 2018", fontsize = 9, fontstyle = 'italic')
ax3.text(0, 0, "49%", ha='center', va='center', fontsize=16, fontweight='bold', color="black")


#Stacked Line Chart
ax4.stackplot(
    
    brazil_vs_rest_of_world_year_comparison.index,
    brazil_vs_rest_of_world_year_comparison["Brazil"],
    brazil_vs_rest_of_world_year_comparison["Rest of World"],
    colors = ["#009739", "#808080"]
)

ax4.set_title("Brazil's Share of Market Grows as Global Output Surges", fontsize = 9, fontstyle = 'italic')
ax4.set_ylabel("Production (Millions 60 kg Bags)", fontsize = 9)
ax4.set_xlabel("Year", fontsize = 9)

ax4.legend(brazil_vs_rest_of_world_year_comparison.columns)

ax4.set_xticks(brazil_vs_rest_of_world_year_comparison.index[2::4])
ax4.tick_params(axis='y', labelsize=8)
ax4.tick_params(axis='x', labelsize=8)


#BarChart
ax5.barh(
    top_5_and_rest_df_for_bar["country"], top_5_and_rest_df_for_bar["production_amount"],
    color = flag_colors
)

ax5.set_title("Top Coffee Producing Nations 1990-2018", fontsize = 9, fontstyle = 'italic')
ax5.set_xlabel("Production (Millions 60 kg Bags)", fontsize = 8)
ax5.tick_params(axis='y', labelsize=8)
ax5.tick_params(axis='x', labelsize=8)

#Pie Chart
ax6.pie(
    x = top_5_vs_rest_2018["production_amount"],
    startangle = 340,
    labels = top_5_vs_rest_2018["country"],
    colors = ["#009739", "#FF0000", "#FFD700", "#0F47AF", "#DA251D", "#808080"],
    autopct = "%0.0f%%",  
    textprops = {'fontsize': 8},
    explode = [0.08, 0, 0, 0, 0, 0],
     wedgeprops = {'edgecolor': 'white', 'linewidth': 1}
)

ax6.set_title("Share of Global Coffee Production 2018", fontsize = 9, fontstyle = 'italic')


#Write Text at the top left explaining the data

ax1.axis('off')

ax1.text(
    0.5, 0.5,
    "Brazil is the world's top coffee grower.\n"
    "Since 1990, Brazil's share of global production\n"
    "has risen from 29% to 49% in 2018.",
    fontsize=10,
    ha='center',
    va='center',
    color = "#009739",
    fontstyle = "italic",
    fontweight = "bold",
    fontfamily = 'serif'
)


fig.suptitle("Brazil Extend its Dominance in Growing Coffee Market", fontsize=14, fontweight='bold', fontfamily = 'serif')
plt.tight_layout();

# %%
#Read in prices-paid-to-growers.csv and create a subplot grid of histograms 
#Showing distribution of prices paid to Brazil, Colombia, Ethiopia, and one for all other nations

# %%
prices_paid_to_growers= pd.read_csv("/Users/huzaifamalik/Downloads/Python for Data Analytics/Data Visualization with Matplotlib & Seaborn/Data Viz with Matplotlib & Seaborn/Data/coffee/prices-paid-to-growers.csv")

# %%
prices_paid_to_growers
# Out:
#    prices_paid_to_growers      1990      1991      1992      1993      1994  \
# 0                Colombia  1.534724  1.481790  1.204656  1.106477  1.898327
# 1      Dominican Republic  1.458168  1.382845  1.027841  1.172704  2.478234
# 2             El Salvador  1.116194  0.983322  0.682322  0.780397  2.191177
# 3               Guatemala  1.204956  1.270086  0.888099  0.914552  1.662711
# 4                Honduras  1.111470  1.238947  0.886057  0.828746  1.800576
# 5                   India  1.473558  1.358371  1.191159  1.278669  1.730810
# 6                  Uganda  0.337598  0.654322  0.441397  0.552298  1.666651
# 7                  Brazil  1.199223  0.971150  0.997768  1.167263  2.529110
# 8                Ethiopia  1.348565  1.505322  1.351128  1.362442  2.418234
# 9                  Brazil  0.769285  0.606947  0.609155  0.784638  1.885786
# 10                  India  0.978921  0.897289  0.877945  0.975912  1.246437
# ...

# %%
brazil = []
colombia =[]
ethiopia = []
others = []

for i in range(0,prices_paid_to_growers.shape[0],1):
    country = prices_paid_to_growers.iloc[i,0]
    
    for j in range(1,prices_paid_to_growers.shape[1],1):
        
        if country == "Brazil":
            brazil.append(float(prices_paid_to_growers.iloc[i,j]))
            
        elif country == "Colombia":
            colombia.append(float(prices_paid_to_growers.iloc[i,j]))
            
        elif country == "Ethiopia":
            ethiopia.append(float(prices_paid_to_growers.iloc[i,j]))
            
        else:
            others.append(float(prices_paid_to_growers.iloc[i,j]))

# %%
series_for_histograms = pd.DataFrame.from_dict(
    {"Brazil": brazil, "Colombia": colombia, "Ethiopia": ethiopia, "Others": others}, orient='index'
).transpose()

# %%
series_for_histograms
# Out:
#        Brazil  Colombia  Ethiopia    Others
# 0    1.199223  1.534724  1.348565  1.458168
# 1    0.971150  1.481790  1.505322  1.382845
# 2    0.997768  1.204656  1.351128  1.027841
# 3    1.167263  1.106477  1.362442  1.172704
# 4    2.529110  1.898327  2.418234  2.478234
# ..        ...       ...       ...       ...
# 256       NaN       NaN       NaN  1.549219
# 257       NaN       NaN       NaN  1.329269
# 258       NaN       NaN       NaN  1.311532
# 259       NaN       NaN       NaN  1.411808
# 260       NaN       NaN       NaN  1.263373
#
# [261 rows x 4 columns]

# %%
fig, ax = plt.subplots(2,2, figsize = (10,10))

regions = ["Brazil", "Colombia", "Ethiopia", "Others"]

for index, region in enumerate(regions):
    
    row = index//2
    col = index%2
    
    ax[row][col].hist(series_for_histograms[region].dropna())
    ax[row][col].set_title(region)

plt.tight_layout();
